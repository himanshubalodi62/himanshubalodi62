# %%
l = [3,4,5,6,7, [23,456,67,8,78,],[345,56,87,8,98,9],(234,6657,6),{'key1':'himu',234:[23,48,656]}]

# %%
## reverse list

# %%
l[::-1]
# Out:
# [{'key1': 'himu', 234: [23, 48, 656]},
#  (234, 6657, 6),
#  [345, 56, 87, 8, 98, 9],
#  [23, 456, 67, 8, 78],
#  7,
#  6,
#  5,
#  4,
#  3]

# %%
l.reverse()

# %%
l
# Out:
# [3,
#  4,
#  5,
#  6,
#  7,
#  [23, 456, 67, 8, 78],
#  [345, 56, 87, 8, 98, 9],
#  (234, 6657, 6),
#  {'key1': 'himu', 234: [23, 48, 656]}]

# %%
l[7][0] ## extract 234 out of the list.
# Out:
# 234

# %%
l[8]
# Out:
# {'key1': 'himu', 234: [23, 48, 656]}

# %%
l[8].keys()
# Out:
# dict_keys(['key1', 234])

# %%
list(l[8].keys())[1]
# Out:
# 234

# %%
l[5] #extract 456.
# Out:
# [23, 456, 67, 8, 78]

# %%
l[5][1]
# Out:
# 456

# %%
## list collecation

# %%
l[5:7]
# Out:
# [[23, 456, 67, 8, 78], [345, 56, 87, 8, 98, 9]]

# %%
l[5]
# Out:
# [23, 456, 67, 8, 78]

# %%
l[6]
# Out:
# [345, 56, 87, 8, 98, 9]

# %%
l[8] # extract himu
# Out:
# {'key1': 'himu', 234: [23, 48, 656]}

# %%
l[8]['key1']
# Out:
# 'himu'

# %%
## extract element from dict

# %%
list(l[8].keys())
# Out:
# ['key1', 234]

# %%
## extract all the value form dict

# %%
l[8]
# Out:
# {'key1': 'himu', 234: [23, 48, 656]}

# %%
l[8].values()
# Out:
# dict_values(['himu', [23, 48, 656]])

# %%
list(l[8].keys())
# Out:
# ['key1', 234]
